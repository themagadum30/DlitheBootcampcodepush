# %%
import pandas as pd

# %%
import pandas as pd
data = {
    "Name": ["Jaggu", "Priya", "Amit", "Sneha", "Rahul"],
    "Age": [23, 22, 20, 23, 21],
    "Department": ["IT", "HR", "IT", "Finance", "HR"],
    "Salary": [50000, 60000, 45000, 70000, 55000]
}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age Department  Salary
# 0  Jaggu   23         IT   50000
# 1  Priya   22         HR   60000
# 2   Amit   20         IT   45000
# 3  Sneha   23    Finance   70000
# 4  Rahul   21         HR   55000

# %%
df.loc[len(df)] = ["Anjali", 24, "IT", 65000]
print(df)
# Out:
#      Name  Age Department  Salary
# 0   Jaggu   23         IT   50000
# 1   Priya   22         HR   60000
# 2    Amit   20         IT   45000
# 3   Sneha   23    Finance   70000
# 4   Rahul   21         HR   55000
# 5  Anjali   24         IT   65000

# %%
df = df.drop(2)
print(df)
# Out:
#      Name  Age Department  Salary
# 0   Jaggu   23         IT   50000
# 1   Priya   22         HR   60000
# 3   Sneha   23    Finance   70000
# 4   Rahul   21         HR   55000
# 5  Anjali   24         IT   65000

# %%
print(df)
# Out:
#      Name  Age Department  Salary
# 0   Jaggu   23         IT   50000
# 1   Priya   22         HR   60000
# 3   Sneha   23    Finance   70000
# 4   Rahul   21         HR   55000
# 5  Anjali   24         IT   65000

# %%
print(data)
# Out:
# {'Name': ['Jaggu', 'Priya', 'Amit', 'Sneha', 'Rahul'], 'Age': [23, 22, 20, 23, 21], 'Department': ['IT', 'HR', 'IT', 'Finance', 'HR'], 'Salary': [50000, 60000, 45000, 70000, 55000]}

# %%
print(pd.DataFrame(data))
# Out:
#     Name  Age Department  Salary
# 0  Jaggu   23         IT   50000
# 1  Priya   22         HR   60000
# 2   Amit   20         IT   45000
# 3  Sneha   23    Finance   70000
# 4  Rahul   21         HR   55000

# %%
df = df.drop([1, 3])
print(df)
# Out:
#      Name  Age Department  Salary
# 0   Jaggu   23         IT   50000
# 4   Rahul   21         HR   55000
# 5  Anjali   24         IT   65000

# %%
df = df.drop("Age", axis=1)
print(df)
# Out:
#      Name Department  Salary
# 0   Jaggu         IT   50000
# 4   Rahul         HR   55000
# 5  Anjali         IT   65000

# %%
df = df.rename(columns={"Employee_Name": "EmpName"})
print(df)
# Out:
#   EmpName Department  Salary
# 0   Jaggu         IT   50000
# 4   Rahul         HR   55000
# 5  Anjali         IT   65000

# %%
df.sort_values(by="Employee_Salary")
# Out:
#   EmpName Department  Employee_Salary
# 0   Jaggu         IT            50000
# 4   Rahul         HR            55000
# 5  Anjali         IT            65000

# %%
print(df)
# Out:
#   EmpName Department  Employee_Salary
# 0   Jaggu         IT            50000
# 4   Rahul         HR            55000
# 5  Anjali         IT            65000

# %%
df.sort_values(by="Employee_Salary", ascending=True)
# Out:
#   EmpName Department  Employee_Salary
# 0   Jaggu         IT            50000
# 4   Rahul         HR            55000
# 5  Anjali         IT            65000

# %%
df.sort_values(by="Employee_Salary", ascending=False)
# Out:
#   EmpName Department  Employee_Salary
# 5  Anjali         IT            65000
# 4   Rahul         HR            55000
# 0   Jaggu         IT            50000

# %%
df.sort_values(
    by=["Department", "Employee_Salary"],
    ascending=[True, False]
)
# Out:
#   EmpName Department  Employee_Salary
# 4   Rahul         HR            55000
# 5  Anjali         IT            65000
# 0   Jaggu         IT            50000

# %%
df.sort_values(
    by=["Department", "Employee_Salary"],
    ascending=[True, True]
)
# Out:
#   EmpName Department  Employee_Salary
# 4   Rahul         HR            55000
# 0   Jaggu         IT            50000
# 5  Anjali         IT            65000

# %%
df.sort_values(
    by=["Department", "Employee_Salary"],
    ascending=[False, True]
)
# Out:
#   EmpName Department  Employee_Salary
# 0   Jaggu         IT            50000
# 5  Anjali         IT            65000
# 4   Rahul         HR            55000

# %%
df["EmpName"] = df["EmpName"].str.upper()
print(df)
# Out:
#   EmpName Department  Employee_Salary
# 0   JAGGU         IT            50000
# 4   RAHUL         HR            55000
# 5  ANJALI         IT            65000

# %%
df["EmpName"] = df["EmpName"].str.lower()
print(df)
# Out:
#   EmpName Department  Employee_Salary
# 0   jaggu         IT            50000
# 4   rahul         HR            55000
# 5  anjali         IT            65000

# %%
df["New_Salary"] = df["Employee_Salary"].apply(lambda x: x + 5000)
print(df)
# Out:
#   EmpName Department  Employee_Salary  New_Salary
# 0   jaggu         IT            50000       55000
# 4   rahul         HR            55000       60000
# 5  anjali         IT            65000       70000

# %%
df["Department"] = df["Department"].map({
    "IT": "Information Technology",
    "HR": "Human Resources",
    "Finance": "Finance Department"
})

# %%
print(df)
# Out:
#   EmpName              Department  Employee_Salary  New_Salary
# 0   jaggu  Information Technology            50000       55000
# 4   rahul         Human Resources            55000       60000
# 5  anjali  Information Technology            65000       70000

# %%
df["Department_Code"] = df["Department"].map({
    "Information Technology": 101,
    "Human Resources": 102,
    "Finance Department": 103
})
print(df)
# Out:
#   EmpName              Department  Employee_Salary  New_Salary  \
# 0   jaggu  Information Technology            50000       55000
# 4   rahul         Human Resources            55000       60000
# 5  anjali  Information Technology            65000       70000
#
#    Department_Code
# 0              101
# 4              102
# 5              101

# %%
df["Department"] = df["Department"].replace({
    "IT": "Information Technology",
    "HR": "Human Resources"
})

# %%
print(df)
# Out:
#   EmpName              Department  Employee_Salary  New_Salary  \
# 0   jaggu  Information Technology            50000       55000
# 4   rahul         Human Resources            55000       60000
# 5  anjali  Information Technology            65000       70000
#
#    Department_Code
# 0              101
# 4              102
# 5              101

# %%
df.describe()
# Out:
#        Employee_Salary    New_Salary  Department_Code
# count         3.000000      3.000000         3.000000
# mean      56666.666667  61666.666667       101.333333
# std        7637.626158   7637.626158         0.577350
# min       50000.000000  55000.000000       101.000000
# 25%       52500.000000  57500.000000       101.000000
# 50%       55000.000000  60000.000000       101.000000
# 75%       60000.000000  65000.000000       101.500000
# max       65000.000000  70000.000000       102.000000

# %%
import pandas as pd

# %%
data = {
    "Employee_ID": [101, 102, 103, 104, 105],
    "Name": ["Ravi", "Priya", "Amit", "Sneha", "Rahul"],
    "Department": ["IT", "HR", "IT", "Finance", "HR"],
    "Salary": [55000, 45000, 70000, 65000, 48000],
    "Experience": [2, 5, 4, 6, 3]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Employee_ID   Name Department  Salary  Experience
# 0          101   Ravi         IT   55000           2
# 1          102  Priya         HR   45000           5
# 2          103   Amit         IT   70000           4
# 3          104  Sneha    Finance   65000           6
# 4          105  Rahul         HR   48000           3

# %%
high_salary = df[df["Salary"] > 50000]

print(high_salary)
# Out:
#    Employee_ID   Name Department  Salary  Experience
# 0          101   Ravi         IT   55000           2
# 2          103   Amit         IT   70000           4
# 3          104  Sneha    Finance   65000           6

# %%
experienced = df[df["Experience"] > 3]

print(experienced)
# Out:
#    Employee_ID   Name Department  Salary  Experience
# 1          102  Priya         HR   45000           5
# 2          103   Amit         IT   70000           4
# 3          104  Sneha    Finance   65000           6

# %%
average_salary = df["Salary"].mean()

print("Average Salary:", average_salary)
# Out:
# Average Salary: 56600.0

# %%
highest_paid = df[df["Salary"] == df["Salary"].max()]

print(highest_paid)
# Out:
#    Employee_ID  Name Department  Salary  Experience
# 2          103  Amit         IT   70000           4

# %%
import pandas as pd
import numpy as np

sales_data = {
    "Order_ID": [1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008],
    "Product": ["Laptop", "Mobile", "Laptop", "Headphones",
                "Mobile", "Laptop", "Headphones", "Mobile"],
    "Category": ["Electronics", "Electronics", "Electronics", "Accessories",
                 "Electronics", "Electronics", "Accessories", "Electronics"],
    "Quantity": [2, 3, 1, 5, 2, 1, 4, 3],
    "Price": [50000, 20000, 50000, 2000,
              20000, 50000, 2000, 20000],
    "Region": ["North", "South", "North", "East",
               "West", "South", "East", "West"]
}

df_sales = pd.DataFrame(sales_data)

print(df_sales)
# Out:
#    Order_ID     Product     Category  Quantity  Price Region
# 0      1001      Laptop  Electronics         2  50000  North
# 1      1002      Mobile  Electronics         3  20000  South
# 2      1003      Laptop  Electronics         1  50000  North
# 3      1004  Headphones  Accessories         5   2000   East
# 4      1005      Mobile  Electronics         2  20000   West
# 5      1006      Laptop  Electronics         1  50000  South
# 6      1007  Headphones  Accessories         4   2000   East
# 7      1008      Mobile  Electronics         3  20000   West

# %%
df_sales["Total_Amount"] = df_sales["Quantity"] * df_sales["Price"]

print(df_sales)
# Out:
#    Order_ID     Product     Category  Quantity  Price Region  Total_Amount
# 0      1001      Laptop  Electronics         2  50000  North        100000
# 1      1002      Mobile  Electronics         3  20000  South         60000
# 2      1003      Laptop  Electronics         1  50000  North         50000
# 3      1004  Headphones  Accessories         5   2000   East         10000
# 4      1005      Mobile  Electronics         2  20000   West         40000
# 5      1006      Laptop  Electronics         1  50000  South         50000
# 6      1007  Headphones  Accessories         4   2000   East          8000
# 7      1008      Mobile  Electronics         3  20000   West         60000

# %%
total_revenue = df_sales["Total_Amount"].sum()

print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 378000

# %%
best_selling = df_sales.groupby("Product")["Quantity"].sum()

print(best_selling)
# Out:
# Product
# Headphones    9
# Laptop        4
# Mobile        8
# Name: Quantity, dtype: int64

# %%
best_product = best_selling.idxmax()

print("Best Selling Product:", best_product)
# Out:
# Best Selling Product: Headphones

# %%
print("Quantity Sold:", best_selling.max())
# Out:
# Quantity Sold: 9

# %%
category_revenue = df_sales.groupby("Category")["Total_Amount"].sum()

print(category_revenue)
# Out:
# Category
# Accessories     18000
# Electronics    360000
# Name: Total_Amount, dtype: int64

# %%
highest_category = category_revenue.idxmax()

print("Highest Revenue Category:", highest_category)
# Out:
# Highest Revenue Category: Electronics

# %%
region_sales = df_sales.groupby("Region")["Total_Amount"].sum()

print(region_sales)
# Out:
# Region
# East      18000
# North    150000
# South    110000
# West     100000
# Name: Total_Amount, dtype: int64

# %%
top_region = region_sales.idxmax()

print("Region with Highest Sales:", top_region)
# Out:
# Region with Highest Sales: North

# %%
top_5_orders = df_sales.sort_values(
    by="Total_Amount",
    ascending=False
).head(5)

print(top_5_orders)
# Out:
#    Order_ID Product     Category  Quantity  Price Region  Total_Amount
# 0      1001  Laptop  Electronics         2  50000  North        100000
# 1      1002  Mobile  Electronics         3  20000  South         60000
# 7      1008  Mobile  Electronics         3  20000   West         60000
# 2      1003  Laptop  Electronics         1  50000  North         50000
# 5      1006  Laptop  Electronics         1  50000  South         50000

# %%
print(df_sales.duplicated())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# dtype: bool

# %%
print("Duplicate Records:", df_sales.duplicated().sum())
# Out:
# Duplicate Records: 0

# %%
df_sales = df_sales.drop_duplicates()

print(df_sales)
# Out:
#    Order_ID     Product     Category  Quantity  Price Region  Total_Amount
# 0      1001      Laptop  Electronics         2  50000  North        100000
# 1      1002      Mobile  Electronics         3  20000  South         60000
# 2      1003      Laptop  Electronics         1  50000  North         50000
# 3      1004  Headphones  Accessories         5   2000   East         10000
# 4      1005      Mobile  Electronics         2  20000   West         40000
# 5      1006      Laptop  Electronics         1  50000  South         50000
# 6      1007  Headphones  Accessories         4   2000   East          8000
# 7      1008      Mobile  Electronics         3  20000   West         60000

# %%
print(df_sales.isnull().sum())
# Out:
# Order_ID        0
# Product         0
# Category        0
# Quantity        0
# Price           0
# Region          0
# Total_Amount    0
# dtype: int64

# %%
df_sales["Quantity"] = df_sales["Quantity"].fillna(
    df_sales["Quantity"].mean()
)

df_sales["Price"] = df_sales["Price"].fillna(
    df_sales["Price"].mean()
)

# %%
df_sales["Product"] = df_sales["Product"].fillna("Unknown")

df_sales["Category"] = df_sales["Category"].fillna("Unknown")

df_sales["Region"] = df_sales["Region"].fillna("Unknown")

# %%
df_sales["Total_Amount"] = (
    df_sales["Quantity"] * df_sales["Price"]
)

# %%
df_sales.to_csv("cleaned_sales.csv", index=False)
print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("customer_churn.csv")

df.head()
# Out:
#    Customer_ID        Name  Gender  Age  Tenure  MonthlyCharges  SupportCalls  \
# 0         1001  Customer_1    Male   34      20            1279             1
# 1         1002  Customer_2  Female   26     113             814             0
# 2         1003  Customer_3    Male   50      61             536             2
# 3         1004  Customer_4    Male   70     106             647             4
# 4         1005  Customer_5    Male   37      35             926             1
#
#   Churn
# 0    No
# 1   Yes
# 2    No
# 3   Yes
# 4    No

# %%
df.head()
# Out:
#    Customer_ID        Name  Gender  Age  Tenure  MonthlyCharges  SupportCalls  \
# 0         1001  Customer_1    Male   34      20            1279             1
# 1         1002  Customer_2  Female   26     113             814             0
# 2         1003  Customer_3    Male   50      61             536             2
# 3         1004  Customer_4    Male   70     106             647             4
# 4         1005  Customer_5    Male   37      35             926             1
#
#   Churn
# 0    No
# 1   Yes
# 2    No
# 3   Yes
# 4    No

# %%
df.tail()
# Out:
#      Customer_ID           Name  Gender  Age  Tenure  MonthlyCharges  \
# 995         1996   Customer_996    Male   64      12             698
# 996         1997   Customer_997    Male   40      17            1014
# 997         1998   Customer_998  Female   66      16            1003
# 998         1999   Customer_999  Female   26      12            1060
# 999         2000  Customer_1000    Male   52       8             798
#
#      SupportCalls Churn
# 995             7    No
# 996             3    No
# 997             4   Yes
# 998             3    No
# 999             0   Yes

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.dtypes
# Out:
# Customer_ID        int64
# Name              object
# Gender            object
# Age                int64
# Tenure             int64
# MonthlyCharges     int64
# SupportCalls       int64
# Churn             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer_ID     1000 non-null   int64
#  1   Name            1000 non-null   object
#  2   Gender          1000 non-null   object
#  3   Age             1000 non-null   int64
#  4   Tenure          1000 non-null   int64
#  5   MonthlyCharges  1000 non-null   int64
#  6   SupportCalls    1000 non-null   int64
#  7   Churn           1000 non-null   object
# dtypes: int64(5), object(3)
# memory usage: 62.6+ KB

# %%
df.isnull().sum()
# Out:
# Customer_ID       0
# Name              0
# Gender            0
# Age               0
# Tenure            0
# MonthlyCharges    0
# SupportCalls      0
# Churn             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop_duplicates()

# %%
df.describe()
# Out:
#        Customer_ID          Age      Tenure  MonthlyCharges  SupportCalls
# count  1000.000000  1000.000000  1000.00000     1000.000000   1000.000000
# mean   1500.500000    44.294000    59.00100      897.955000      3.974000
# std     288.819436    15.420485    34.50202      336.538543      2.622251
# min    1001.000000    18.000000     1.00000      300.000000      0.000000
# 25%    1250.750000    31.000000    29.00000      606.750000      2.000000
# 50%    1500.500000    44.000000    59.00000      881.000000      4.000000
# 75%    1750.250000    57.000000    89.00000     1198.000000      6.000000
# max    2000.000000    70.000000   120.00000     1499.000000      8.000000

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     792
# Yes    208
# Name: count, dtype: int64

# %%
df["Churn"].value_counts().plot(kind="bar")
plt.title("Customer Churn Count")
plt.xlabel("Churn")
plt.ylabel("Number of Customers")

plt.show()

# %%
df.groupby("Churn")["MonthlyCharges"].mean()
# Out:
# Churn
# No     878.786616
# Yes    970.942308
# Name: MonthlyCharges, dtype: float64

# %%
df[df["Churn"] == "Yes"]["Tenure"].mean()
# Out:
# 58.35096153846154

# %%
churned = df[df["Churn"] == "Yes"]

# %%
churned["Gender"].value_counts()
# Out:
# Gender
# Male      105
# Female    103
# Name: count, dtype: int64

# %%
churned["Gender"].value_counts().idxmax()
# Out:
# 'Male'

# %%
df.groupby("Churn")["SupportCalls"].mean()
# Out:
# Churn
# Yes    4.538462
# Name: SupportCalls, dtype: float64

# %%
result = df[
    (df["MonthlyCharges"] > 1000) &
    (df["SupportCalls"] > 3) &
    (df["Churn"] == "Yes")
]
print(result)
# Out:
#      Customer_ID          Name  Gender  Age  Tenure  MonthlyCharges  \
# 20          1021   Customer_21  Female   47      14            1037
# 27          1028   Customer_28  Female   49      92            1069
# 37          1038   Customer_38    Male   30      40            1424
# 68          1069   Customer_69  Female   62      67            1198
# 74          1075   Customer_75    Male   49      77            1216
# ..           ...           ...     ...  ...     ...             ...
# 947         1948  Customer_948  Female   47      49            1303
# 964         1965  Customer_965    Male   54       3            1086
# 988         1989  Customer_989  Female   43      55            1119
# 989         1990  Customer_990  Female   58      80            1163
# 997         1998  Customer_998  Female   66      16            1003
#
#      SupportCalls Churn
# 20              4   Yes
# 27              4   Yes
# 37              7   Yes
# 68              5   Yes
# ...

# %%
df = pd.read_csv("hospital_data.csv")

# %%
df.isnull().sum()
# Out:
# Patient_ID        0
# Name              0
# Age               8
# Gender            0
# Department        5
# Treatment_Cost    7
# Outcome           0
# Admission_Days    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 5

# %%
df = df.drop_duplicates()

# %%
df["Age"].describe()
# Out:
# count    992.000000
# mean      44.039315
# std       26.421054
# min        1.000000
# 25%       21.000000
# 50%       43.000000
# 75%       68.000000
# max       90.000000
# Name: Age, dtype: float64

# %%
df["Age"].plot(kind="hist", bins=10)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Number of Patients")

plt.show()

# %%
df.groupby("Department")["Treatment_Cost"].mean()
# Out:
# Department
# Cardiology           96762.805556
# General Medicine     59496.222222
# Neurology           100748.828221
# Oncology            123784.717105
# Orthopedics          84792.588235
# Pediatrics           57029.603550
# Name: Treatment_Cost, dtype: float64

# %%
department_count = df["Department"].value_counts()
print(department_count)
# Out:
# Department
# Cardiology          180
# General Medicine    172
# Pediatrics          171
# Neurology           164
# Orthopedics         154
# Oncology            154
# Name: count, dtype: int64

# %%
print(department_count.idxmax())
# Out:
# Cardiology

# %%
df.groupby("Outcome")["Treatment_Cost"].mean()
# Out:
# Outcome
# Critical           90375.130435
# Deceased           82019.533333
# Recovered          87532.874242
# Under Treatment    83800.850829
# Name: Treatment_Cost, dtype: float64

# %%
Q1 = df["Treatment_Cost"].quantile(0.25)
Q3 = df["Treatment_Cost"].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

outliers = df[
    (df["Treatment_Cost"] < lower_limit) |
    (df["Treatment_Cost"] > upper_limit)
]

print(outliers)
# Out:
#      Patient_ID         Name   Age  Gender        Department  Treatment_Cost  \
# 4         10005    Patient_5  64.0    Male        Pediatrics        291880.0
# 39        10040   Patient_40  60.0    Male  General Medicine        335405.0
# 123       10124  Patient_124  36.0    Male        Pediatrics        237480.0
# 166       10167  Patient_167  21.0    Male          Oncology        707976.0
# 448       10449  Patient_449  42.0  Female         Neurology        346713.0
# 533       10534  Patient_534   2.0    Male        Pediatrics        248980.0
# 639       10640  Patient_640  70.0  Female         Neurology        224067.0
# 718       10719  Patient_719  50.0  Female               NaN        476340.0
# 818       10819  Patient_819  33.0    Male        Cardiology        628945.0
# 844       10845  Patient_845  57.0  Female       Orthopedics        398964.0
# 853       10854  Patient_854  40.0    Male       Orthopedics        567804.0
# ...

# %%
df.boxplot(column="Treatment_Cost")
plt.title("Treatment Cost Outliers")
plt.show()

# %%
correlation = df["Admission_Days"].corr(
    df["Treatment_Cost"]
)
print("Correlation:", correlation)
# Out:
# Correlation: 0.40604771276735796

# %%
plt.scatter(
    df["Admission_Days"],
    df["Treatment_Cost"]
)
plt.xlabel("Admission Days")
plt.ylabel("Treatment Cost")
plt.title("Admission Days vs Treatment Cost")

plt.show()

# %%
df["Admission_Days"].corr(df["Treatment_Cost"])
# Out:
# 0.40604771276735796

# %%
df.groupby("Department")["Treatment_Cost"].mean()
# Out:
# Department
# Cardiology           96762.805556
# General Medicine     59496.222222
# Neurology           100748.828221
# Oncology            123784.717105
# Orthopedics          84792.588235
# Pediatrics           57029.603550
# Name: Treatment_Cost, dtype: float64

# %%
df.groupby("Department")["Treatment_Cost"].sum()
df.groupby("Department")["Treatment_Cost"].max()
df.groupby("Department").size()
# Out:
# Department
# Cardiology          180
# General Medicine    172
# Neurology           164
# Oncology            154
# Orthopedics         154
# Pediatrics          171
# dtype: int64

# %%
df.groupby("Department")["Treatment_Cost"].agg([
    "count",
    "mean",
    "min",
    "max",
    "sum"
])
# Out:
#                   count           mean      min       max         sum
# Department
# Cardiology          180   96762.805556  58383.0  628945.0  17417305.0
# General Medicine    171   59496.222222  23466.0  335405.0  10173854.0
# Neurology           163  100748.828221  64459.0  346713.0  16422059.0
# Oncology            152  123784.717105  83670.0  707976.0  18815277.0
# Orthopedics         153   84792.588235  43743.0  567804.0  12973266.0
# Pediatrics          169   57029.603550  17137.0  291880.0   9638003.0
