# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix
)

# %%
data = {
    "Radius": [8, 9, 10, 11, 12, 14, 15, 16, 18, 20,
               7, 9, 11, 13, 17, 19, 21, 8, 10, 16],

    "Texture": [10, 12, 15, 14, 18, 20, 22, 24, 25, 30,
                8, 11, 16, 19, 23, 27, 32, 9, 14, 25],

    "Perimeter": [50, 55, 60, 65, 70, 80, 85, 90, 100, 110,
                  45, 52, 62, 75, 95, 105, 115, 48, 58, 92],

    "Area": [180, 220, 250, 300, 350, 450, 500, 550, 700, 800,
             150, 200, 280, 380, 600, 750, 900, 170, 240, 580],

    "Smoothness": [0.05, 0.06, 0.07, 0.08, 0.09, 0.10, 0.11, 0.12, 0.13, 0.14,
                   0.04, 0.06, 0.07, 0.09, 0.12, 0.13, 0.15, 0.05, 0.07, 0.12],

    "Diagnosis": [
        "Benign", "Benign", "Benign", "Benign", "Benign",
        "Malignant", "Malignant", "Malignant", "Malignant", "Malignant",
        "Benign", "Benign", "Benign", "Benign", "Malignant",
        "Malignant", "Malignant", "Benign", "Benign", "Malignant"
    ]
}

df = pd.DataFrame(data)

df
# Out:
#     Radius  Texture  Perimeter  Area  Smoothness  Diagnosis
# 0        8       10         50   180        0.05     Benign
# 1        9       12         55   220        0.06     Benign
# 2       10       15         60   250        0.07     Benign
# 3       11       14         65   300        0.08     Benign
# 4       12       18         70   350        0.09     Benign
# 5       14       20         80   450        0.10  Malignant
# 6       15       22         85   500        0.11  Malignant
# 7       16       24         90   550        0.12  Malignant
# 8       18       25        100   700        0.13  Malignant
# 9       20       30        110   800        0.14  Malignant
# 10       7        8         45   150        0.04     Benign
# 11       9       11         52   200        0.06     Benign
# 12      11       16         62   280        0.07     Benign
# 13      13       19         75   380        0.09     Benign
# 14      17       23         95   600        0.12  Malignant
# ...

# %%
X = df[
    [
        "Radius",
        "Texture",
        "Perimeter",
        "Area",
        "Smoothness"
    ]
]

y = df["Diagnosis"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=42,
    stratify=y
)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
model = SVC(
    kernel="rbf",
    C=1.0
)

model.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = model.predict(X_test)

print(y_pred)
# Out:
# ['Benign' 'Benign' 'Malignant' 'Malignant' 'Benign']

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       Benign       1.00      1.00      1.00         3
#    Malignant       1.00      1.00      1.00         2
#
#     accuracy                           1.00         5
#    macro avg       1.00      1.00      1.00         5
# weighted avg       1.00      1.00      1.00         5

# %%
cm = confusion_matrix(y_test, y_pred)

print(cm)
# Out:
# [[3 0]
#  [0 2]]

# %%
new_data = [[
    16,    
    24,    
    90,    
    550,   
    0.12   
]]

new_data_scaled = scaler.transform(new_data)

prediction = model.predict(new_data_scaled)

print("Prediction:", prediction[0])
# Out:
# Prediction: Malignant
# c:\Users\thema\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix
)

# %%
data = {
    "Age": [22, 25, 28, 30, 35, 40, 45, 50, 27, 32,
            38, 42, 48, 24, 29, 34, 39, 44, 26, 36],

    "Experience": [1, 2, 3, 5, 8, 12, 15, 20, 3, 6,
                   10, 14, 18, 1, 4, 7, 11, 16, 2, 9],

    "Performance_Score": [50, 55, 60, 70, 85, 90, 92, 95, 62, 75,
                          88, 91, 94, 48, 65, 78, 89, 93, 52, 84],

    "Training_Hours": [5, 8, 10, 15, 25, 30, 35, 40, 12, 18,
                       28, 32, 38, 4, 11, 20, 29, 36, 7, 24],

    "Projects_Completed": [1, 2, 2, 3, 5, 6, 7, 8, 3, 4,
                           6, 7, 8, 1, 2, 4, 6, 8, 2, 5],

    "Promotion": [
        "No", "No", "No", "No", "Yes",
        "Yes", "Yes", "Yes", "No", "Yes",
        "Yes", "Yes", "Yes", "No", "No",
        "Yes", "Yes", "Yes", "No", "Yes"
    ]
}

df = pd.DataFrame(data)

df
# Out:
#     Age  Experience  Performance_Score  Training_Hours  Projects_Completed  \
# 0    22           1                 50               5                   1
# 1    25           2                 55               8                   2
# 2    28           3                 60              10                   2
# 3    30           5                 70              15                   3
# 4    35           8                 85              25                   5
# 5    40          12                 90              30                   6
# 6    45          15                 92              35                   7
# 7    50          20                 95              40                   8
# 8    27           3                 62              12                   3
# 9    32           6                 75              18                   4
# 10   38          10                 88              28                   6
# ...

# %%
X = df[
    [
        "Age",
        "Experience",
        "Performance_Score",
        "Training_Hours",
        "Projects_Completed"
    ]
]

y = df["Promotion"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.25,
    random_state=42,
    stratify=y
)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
model = SVC(
    kernel="rbf",
    C=1.0
)

model.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = model.predict(X_test)

print(y_pred)
# Out:
# ['Yes' 'No' 'Yes' 'Yes' 'Yes']

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       1.00      0.50      0.67         2
#          Yes       0.75      1.00      0.86         3
#
#     accuracy                           0.80         5
#    macro avg       0.88      0.75      0.76         5
# weighted avg       0.85      0.80      0.78         5

# %%
cm = confusion_matrix(y_test, y_pred)

print(cm)
# Out:
# [[1 1]
#  [0 3]]

# %%
new_employee = [[
    35,   
    8,    
    88,   
    25,   
    5     
]]

new_employee_scaled = scaler.transform(new_employee)

prediction = model.predict(new_employee_scaled)

print("Promotion Prediction:", prediction[0])
# Out:
# Promotion Prediction: Yes
# c:\Users\thema\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
